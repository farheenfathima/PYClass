# %% [markdown]
# ### difference between value is the argument, parameters are variables inside functions?

# %%
def my_func():
    my_func() #recursive
    
my_func(); #Dont run it, kills kernel
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-becd00ccb02b> in <module>()
#       2     my_func() #recursive
#       3
# ----> 4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
# ...
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# <ipython-input-3-becd00ccb02b> in my_func()
#       1 def my_func():
# ----> 2     my_func() #recursive
#       3
#       4 my_func()
#
# RuntimeError: maximum recursion depth exceeded
